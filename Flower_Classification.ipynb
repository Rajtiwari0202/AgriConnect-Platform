# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajtiwari0202/AgriConnect-Platform/blob/main/Flower_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading data from drive
from google.colab import drive
drive.mount('dataset')
# Out:
# Mounted at dataset

# %%
ls -A
# Out:
# .config/  dataset/  sample_data/

# %%
#import nessarary libraries
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model

import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import pandas
import os
import random
from tqdm import tqdm

# %%
path = 'dataset/My Drive/Dataset/flowers'
folders = os.listdir(path)
print(folders)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1045/2206356927.py in <cell line: 0>()
#       1 path = 'dataset/My Drive/Dataset/flowers'
# ----> 2 folders = os.listdir(path)
#       3 print(folders)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/My Drive/Dataset/flowers'

# %%
image_names =[]
train_lables =[]
train_images =[]

# %%
# resizing and enumrating lists and transform it into numpy array

size = 64,64

for folder in folders:
  print(folder)
  for file in os.listdir(os.path.join(path,folder)):
    if file.endswith('jpg'):
      image_names.append(os.path.join(path,folder,file))
      train_lables.append(folder)
      img = cv2.imread(os.path.join(path,folder,file))
      img = cv2.resize(img,size)
      train_images.append(img)
    else:
      continue

train = np.array(train_images)
print(train.size)
# Out:
# daisy
# dandelion
# sunflower
# tulip
# rose
# 53231616

# %%
train = train.astype('float32') / 255.0

# extract lables
label_dummies = pandas.get_dummies(train_lables)
labels =  label_dummies.values.argmax(1)

# %%
print(pandas.unique(train_lables))
print(pandas.unique(labels))
# Out:
# ['daisy' 'dandelion' 'sunflower' 'tulip' 'rose']
# [0 1 3 4 2]

# %%
# Shuffle the labels and images randomly for better results

union_list = list(zip(train, labels))
random.shuffle(union_list)
train,labels = zip(*union_list)

# %%
# Convert the shuffled list to numpy array type
train = np.array(train)
labels = np.array(labels)

# %%
# Building a model
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (64,64,3)),
    keras.layers.Dense(128,activation = tf.nn.tanh),
    keras.layers.Dense(5,activation = tf.nn.softmax)
])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# model parameters
model.compile(optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy']
)

# %%
model.fit(train,labels,epochs = 80)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1045/3712066757.py in <cell line: 0>()
# ----> 1 model.fit(train,labels,epochs = 80)
#
# NameError: name 'model' is not defined

# %%
# Saving model
model.save('my_model.h5')
# Out:
# Using TensorFlow backend.

# %%
# saving model to drive
from google.colab import files
files.download('my_model.h5')

# %%
# !pip install -U -q PyDrive
# !git clone https://gist.github.com/dc7e60aa487430ea704a8cb3f2c5d6a6.git /tmp/colab_util_repo
# !mv /tmp/colab_util_repo/colab_util.py colab_util.py
# !rm -r /tmp/colab_util_repo
from colab_util import *
drive_handler = GoogleDriveHandler()
# Out:
#     100% |████████████████████████████████| 993kB 19.7MB/s
#   Building wheel for PyDrive (setup.py) ... done
# Cloning into '/tmp/colab_util_repo'...
# remote: Enumerating objects: 40, done.
# remote: Total 40 (delta 0), reused 0 (delta 0), pack-reused 40
# Unpacking objects: 100% (40/40), done.

# %%
test_folder_id = drive_handler.create_folder('models/flower')
test_folder_id

drive_handler.upload('my_model.h5', parent_path='models/flower')
drive_handler.list_folder(test_folder_id, max_depth=1)
# Out:
# models/flower already exists
# []
